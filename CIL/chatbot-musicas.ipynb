# %%
# !pip install pytelegrambotapi

# %%
import telebot

# %%
API_TOKEN = ''
bot = telebot.TeleBot(API_TOKEN)

# %%
# !pip install pandas pandasai==0.8.4

# %%
import pandas as pd
from pandasai import PandasAI

# %%
from pandasai.llm.starcoder import Starcoder

# %%
llm = Starcoder(api_token="")

# %%
df = pd.read_csv("https://raw.githubusercontent.com/acorreac/bertoti/main/CIL/cinquenta-musicas.csv")

# %%
df.head()
# Out:
#    position               song  streams                  artist  year
# 0         1    Blinding Lights    3.834              The Weeknd  1905
# 1         2       Shape of You    3.649              Ed Sheeran  1905
# 2         3  Someone You Loved    3.004           Lewis Capaldi  1905
# 3         4          Sunflower    2.949  Post Malone e Swae Lee  1905
# 4         5       Dance Monkey    2.914             Tones and I  1905

# %%
pandas_ai = PandasAI(llm, conversational=False)

# %%
res = pandas_ai.run(df, prompt='plot a pie chart with artists by year?')

# %%
res = pandas_ai.run(df, prompt='plot a chart with the number of streams per year?')

# %%
res = pandas_ai.run(df, prompt='print the csv')

# %%
res
# Out:
#     position                      song  streams  \
# 0          1           Blinding Lights    3.834
# 1          2              Shape of You    3.649
# 2          3         Someone You Loved    3.004
# 3          4                 Sunflower    2.949
# 4          5              Dance Monkey    2.914
# 5          6                 One Dance    2.810
# 6          7                  Rockstar    2.786
# 7          8                      Stay    2.780
# 8          9                   Starboy    2.728
# 9         10                 As It Was    2.723
# 10        11                  Believer    2.693
# 11        12                Heat Waves    2.675
# 12        13                   Perfect    2.659
# 13        14                    Closer    2.652
# 14        15                  Señorita    2.546
# 15        16      Say You Won't Let Go    2.502
# 16        17                    Lovely    2.465
# 17        18           Sweater Weather    2.421
# 18        19          Watermelon Sugar    2.414
# 19        20           Don't Start Now    2.376
# 20        21                   Bad Guy    2.362
# 21        22              Lucid Dreams    2.347
# 22        23         Thinking Out Loud    2.333
# 23        24                God's Plan    2.320
# 24        25                Photograph    2.307
# 25        26  Something Just Like This    2.285
# 26        27         Bohemian Rhapsody    2.268
# 27        28         Take Me To Church    2.225
# 28        29                   Shallow    2.223
# 29        30                   Circles    2.219
# 30        31             Love Yourself    2.189
# 31        32                 All of Me    2.148
# 32        33                   Thunder    2.132
# 33        34                   Riptide    2.119
# 34        35            Counting Stars    2.107
# 35        36                      Sad!    2.094
# 36        37                Goosebumps    2.094
# 37        38                   7 Rings    2.093
# 38        39              Stressed Out    2.062
# 39        40             Can't Hold Us    2.054
# 40        41                Wake Me Up    2.052
# 41        42            Jocelyn Flores    2.032
# 42        43                 The Hills    2.027
# 43        44                Let Her Go    2.003
# 44        45                    Humble    1.991
# 45        46             XO Tour Llif3    1.969
# 46        47                  One Kiss    1.966
# 47        48              Another Love    1.958
# 48        49                  Good 4 U    1.958
# 49        50                    Havana    1.951
#
#                                       artist  year
# 0                                 The Weeknd  1905
# 1                                 Ed Sheeran  1905
# 2                              Lewis Capaldi  1905
# 3                     Post Malone e Swae Lee  1905
# 4                                Tones and I  1905
# 5                  Drake feat. Wizkid e Kyla  1905
# 6                Post Malone feat. 21 Savage  1905
# 7              The Kid Laroi e Justin Bieber  1905
# 8                                 The Weeknd  1905
# 9                               Harry Styles  1905
# 10                           Imagine Dragons  2016
# 11                             Glass Animals  2020
# 12                                Ed Sheeran  2017
# 13                          The Chainsmokers  2016
# 14             Shawn Mendes e Camila Cabello  2019
# 15                              James Arthur  2016
# 16                    Billie Eilish e Khalid  2018
# 17                         The Neighbourhood  2012
# 18                              Harry Styles  2020
# 19                                  Dua Lipa  2019
# 20                             Billie Eilish  2019
# 21                                Juice WRLD  2018
# 22                                Ed Sheeran  2014
# 23                                     Drake  2018
# 24                                Ed Sheeran  2014
# 25               The Chainsmokers e Coldplay  2017
# 26                                     Queen  1975
# 27                                    Hozier  2013
# 28                Lady Gaga e Bradley Cooper  2018
# 29                               Post Malone  2019
# 30                             Justin Bieber  2015
# 31                               John Legend  2013
# 32                           Imagine Dragons  2017
# 33                                 Vance Joy  2013
# 34                               OneRepublic  2013
# 35                              XXXTentacion  2018
# 36         Travis Scott feat. Kendrick Lamar  2016
# 37                             Ariana Grande  2019
# 38                         Twenty One Pilots  2015
# 39  Macklemore & Ryan Lewis feat. Ray Dalton  2011
# 40                                    Avicii  2013
# 41                              XXXTentacion  2017
# 42                                The Weeknd  2015
# 43                                 Passenger  2012
# 44                            Kendrick Lamar  2017
# 45                              Lil Uzi Vert  2017
# 46                  Calvin Harris e Dua Lipa  2018
# 47                                 Tom Odell  2013
# 48                            Olivia Rodrigo  2021
# 49           Camila Cabello feat. Young Thug  2017

# %%
res = pandas_ai.run(df, prompt='Which song is in first position?')

# %%
res

# %%
res = pandas_ai.run(df, prompt='Which songs are from 2019?')

# %%
res
# Out:
#     position             song  streams                         artist  year
# 14        15         Señorita    2.546  Shawn Mendes e Camila Cabello  2019
# 19        20  Don't Start Now    2.376                       Dua Lipa  2019
# 20        21          Bad Guy    2.362                  Billie Eilish  2019
# 29        30          Circles    2.219                    Post Malone  2019
# 37        38          7 Rings    2.093                  Ariana Grande  2019

# %%
#######################################################################################################

# %%
@bot.message_handler(func=lambda message: True)
def response(message):

  response = pandas_ai.run(df, prompt=message.text)


  bot.reply_to(message, response['song'].to_string(index=False))

# %%
bot.polling()
